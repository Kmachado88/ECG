# %% [markdown]
# <a href="https://colab.research.google.com/github/Kmachado88/ECG/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import packages
import statistics
import pandas as pd
import scipy.stats as stats
from scipy.stats import sem
from statistics import mean, stdev
import matplotlib.pyplot as plt
import numpy as np
#include if using a jupyter notebook, remove if using a .py file
# %matplotlib inline

# %%
F_VC = [2.7, 3.7, 3.2, 3.45, 3.2,3.1]
M_VC = [3.3,4.5,3.7]

# %%
F_VC
# Out:
# [2.7, 3.7, 3.2, 3.45, 3.2, 3.1]

# %%
M_VC
# Out:
# [3.3, 4.5, 3.7]

# %%
F_VCmean = mean(F_VC)
M_VCmean = mean(M_VC)
FVC_mean, M_VCmean
# Out:
# (3.225, 3.8333333333333335)

# %%
F_VCsem = sem(F_VC)
M_VCsem = sem(M_VC)
F_VCsem, M_VCsem
# Out:
# (0.13768926368215256, 0.3527668414752788)

# %%
plt.bar(['Female VC', 'Male VC'],[F_VCmean,M_VCmean], yerr=[F_VCsem, M_VCsem], capsize=10)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(['Female VC', 'Male VC'],[F_VCmean,M_VCmean], yerr=[F_VCsem, M_VCsem], capsize=10)
plt.xlabel('Biological Sex')
plt.ylabel('Vital Capacity (L)')
plt.title('Vital Capacity Differences in Male vc Female')
# Out:
# Text(0.5, 1.0, 'Vital Capacity Differences in Male vc Female')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-7d78b37754fe> in <cell line: 1>()
# ----> 1 fev1
#
# NameError: name 'fev1' is not defined
